# %% [markdown]
# <a href="https://colab.research.google.com/github/Ariqq16/PCVK_Ganjil_2026/blob/main/P3/TUGAS-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

print("Mengubah kontras dan tingkat kecerahan citra")
print("-" * 43)

brightness = float(input("Masukkan tingkat kecerahan : "))
contrast = float(input("Masukkan kontras : "))

img_path = '/content/drive/MyDrive/PCVK_2026/sunset.jpg'
img = cv.imread(img_path)

if img is None:
    print(f"Error: File tidak ditemukan di {img_path}")
else:

    img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

    contrast_image = np.clip(contrast * img_rgb.astype(np.float32) + brightness, 0, 255).astype(np.uint8)

    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.imshow(img_rgb)
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.imshow(contrast_image)
    plt.axis('off')

    plt.show()
# Out:
# Mengubah kontras dan tingkat kecerahan citra
# -------------------------------------------
# Masukkan tingkat kecerahan : 35
# Masukkan kontras : 20
