# %% [markdown]
# <a href="https://colab.research.google.com/github/Ariqq16/PCVK_Ganjil_2026/blob/main/P3/TUGAS-7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

try:
    bit_depth = int(input("Masukkan bit depth tujuan (1-8): "))

    if bit_depth < 1 or bit_depth > 8:
        print("Error: Masukkan angka antara 1 hingga 8.")
    else:
        img_path = '/content/drive/MyDrive/PCVK_2026/peppers.jpg'
        original = cv.imread(img_path, cv.IMREAD_GRAYSCALE)

        if original is None:
            print(f"Error: File tidak ditemukan di {img_path}")
        else:
            num_levels = pow(2, bit_depth)
            level = 255 / (num_levels - 1)

            print(f"Bit depth awal  : 8 bit")
            print(f"Bit depth tujuan: {bit_depth} bit")
            print(f"Jumlah level    : {num_levels}")

            depth_image = (np.round(original / level) * level).astype(np.uint8)

            plt.figure(figsize=(10, 5))

            plt.subplot(1, 2, 1)
            plt.imshow(original, cmap='gray', vmin=0, vmax=255)
            plt.title('Grayscale 8-bit')
            plt.axis('off')

            plt.subplot(1, 2, 2)
            plt.imshow(depth_image, cmap='gray', vmin=0, vmax=255)
            plt.title(f'Grayscale {bit_depth}-bit')
            plt.axis('off')

            plt.show()

except ValueError:
    print('Error, not a number')
# Out:
# Masukkan bit depth tujuan (1-8): 3
# Bit depth awal  : 8 bit
# Bit depth tujuan: 3 bit
# Jumlah level    : 8
